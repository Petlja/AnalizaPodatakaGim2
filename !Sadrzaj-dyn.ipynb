# %% [markdown]
# # Рачунарство и информатика за 2. гимназије
#
# **Циљ** предмета Рачунарство и информатика за 2. гимназије је „стицање знања, овладавање вештинама, формирање вредносних ставова који доприносе развоју информатичке писмености неопходне за даље школовање, живот и рад у савременом друштву“.
#
# Курс ставља фокус на
#
# - податке,
# - обраду података, и
# - визуелизацију података
#
# у три различита контекста:
#
# - програми за табеларна израчунавања,
# - рад са подацима у текстуалном програмском језику (Џупитер), и
# - програмирање у програмском језику Пајтон.
#
# Овде се налази део курса који се односи на Џупитер и Пајтон у облику Џупитер радних свески које могу да се покрену, што омогућује да се код извршава интерактивно и да се на тај начин стекну одговарајуће вештине.
#
# [0. Покретање Џупитер (*Jupyter*) радних свески](sJ00.ipynb)
#
# ### Рад са подацима у текстуалном програмском језику
#
# [1. Увод у Џупитер (*Jupyter*)](sJ01.ipynb)
#
# [2. Низови података и линијски дијаграми](sJ02.ipynb)
#
# [3. Хистограми и боје](sJ03.ipynb)
#
# [4. Просек и медијана низа бројева](sJ04.ipynb)
#
# [5. Фреквенцијска анализа и секторски дијаграми](sJ05.ipynb)
#
# [6. Табеларно представљени подаци](sJ06.ipynb)
#
# [7. Индексирање и транспоновање табеле](sJ07.ipynb)
#
# [8. Модификације табеле и записивање табеле у датотеку](sJ08.ipynb)
#
# [9. Сортирање, филтрирање и фреквенцијска анализа](sJ09.ipynb)
#
# [10. Џупитер и Ексел](sJ10.ipynb)
#
# ### Технике програмирања у програмском језику Пајтон
#
# [1. Увод у процесирање низова података](Y01.ipynb)
#
# [2. Бројачи и суме](Y02.ipynb)
#
# [3. Стрингови](Y03.ipynb)
#
# [4. Текстуалне датотеке](Y04.ipynb)
#
# [5. Угнежђене петље](Y05.ipynb)
#
# [6. Сортирање](Y06.ipynb)
#
# [7. Филтрирање и претраживање](Y07.ipynb)
